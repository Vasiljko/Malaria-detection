# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/
# %cd Machine\ learning
# %cd malaria\ detection
# Out:
# /content/gdrive/MyDrive
# /content/gdrive/MyDrive/Machine learning
# /content/gdrive/MyDrive/Machine learning/malaria detection

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Machine learning/malaria detection/.git/

# %%
# !git remote add origin https://Vasiljko:californiaherewecome123@github.com/Vasiljko/Malaria-detection.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://Vasiljko:californiaherewecome123@github.com/Vasiljko/flowers-classification.git (fetch)
# origin	https://Vasiljko:californiaherewecome123@github.com/Vasiljko/flowers-classification.git (push)
